# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read in health data

# %%
df_health = pd.read_csv('./Data/health.csv')

# %%
df_health.head()
# Out:
#   StateAbbr   PlaceName  PlaceFIPS   TractFIPS        Place_TractID  \
# 0        AL  Birmingham     107000  1073000100  0107000-01073000100
# 1        AL  Birmingham     107000  1073000300  0107000-01073000300
# 2        AL  Birmingham     107000  1073000400  0107000-01073000400
# 3        AL  Birmingham     107000  1073000500  0107000-01073000500
# 4        AL  Birmingham     107000  1073000700  0107000-01073000700
#
#    Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  \
# 0            3042               23.9      (21.2, 27.2)                 32.5
# 1            2735               28.8      (25.4, 32.4)                 31.3
# 2            3338               26.1      (22.6, 29.9)                 34.6
# 3            2864               28.1      (24.6, 32.0)                 37.8
# 4            2577               31.8      (27.0, 36.7)                 38.5
#
#   ARTHRITIS_Crude95CI                ...                 PAPTEST_Crude95CI  \
# ...

# %% [markdown]
# # Filter only New York City

# %%
df_ny = df_health[df_health['StateAbbr'] == 'NY']

# %%
np.unique(df_ny['PlaceName'])
# Out:
# array(['Albany', 'Buffalo', 'Mount Vernon', 'New Rochelle', 'New York',
#        'Rochester', 'Schenectady', 'Syracuse', 'Yonkers'], dtype=object)

# %%
df_nyc = df_ny[df_ny['PlaceName'] == 'New York']
df_nyc.shape
# Out:
# (2117, 63)

# %%
df_nyc.head()
# Out:
#       StateAbbr PlaceName  PlaceFIPS    TractFIPS        Place_TractID  \
# 16368        NY  New York    3651000  36005000100  3651000-36005000100
# 16369        NY  New York    3651000  36005000200  3651000-36005000200
# 16370        NY  New York    3651000  36005000400  3651000-36005000400
# 16371        NY  New York    3651000  36005001600  3651000-36005001600
# 16372        NY  New York    3651000  36005001900  3651000-36005001900
#
#        Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 16368           11091               32.0      (27.3, 35.9)
# 16369            4334               19.9      (16.6, 23.2)
# 16370            5503               16.8      (14.1, 20.1)
# 16371            5643               24.5      (20.7, 28.0)
# 16372            1917               23.8      (19.7, 27.9)
#
#        ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  \
# 16368                 13.2        (12.4, 13.9)
# 16369                 19.8        (18.9, 20.7)
# ...

# %%
df_nyc = df_nyc.reset_index(drop=True)
df_nyc.head()
# Out:
#   StateAbbr PlaceName  PlaceFIPS    TractFIPS        Place_TractID  \
# 0        NY  New York    3651000  36005000100  3651000-36005000100
# 1        NY  New York    3651000  36005000200  3651000-36005000200
# 2        NY  New York    3651000  36005000400  3651000-36005000400
# 3        NY  New York    3651000  36005001600  3651000-36005001600
# 4        NY  New York    3651000  36005001900  3651000-36005001900
#
#    Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  \
# 0           11091               32.0      (27.3, 35.9)                 13.2
# 1            4334               19.9      (16.6, 23.2)                 19.8
# 2            5503               16.8      (14.1, 20.1)                 17.8
# 3            5643               24.5      (20.7, 28.0)                 25.1
# 4            1917               23.8      (19.7, 27.9)                 16.7
#
#   ARTHRITIS_Crude95CI                ...                 PAPTEST_Crude95CI  \
# ...

# %%
df_nyc.to_csv('./Data/NYC_Health.csv', index=False)

# %%
df_nyc_subset = df_nyc[['PlaceFIPS', 'TractFIPS', 'Place_TractID',
                'DIABETES_CrudePrev', 'HIGHCHOL_CrudePrev', 'OBESITY_CrudePrev']]
df_nyc_subset.head()
# Out:
#    PlaceFIPS    TractFIPS        Place_TractID  DIABETES_CrudePrev  \
# 0    3651000  36005000100  3651000-36005000100                 9.9
# 1    3651000  36005000200  3651000-36005000200                12.7
# 2    3651000  36005000400  3651000-36005000400                11.2
# 3    3651000  36005001600  3651000-36005001600                17.0
# 4    3651000  36005001900  3651000-36005001900                11.4
#
#    HIGHCHOL_CrudePrev  OBESITY_CrudePrev
# 0                27.8               35.4
# 1                33.8               29.9
# 2                31.4               29.4
# 3                37.8               34.5
# 4                30.8               33.0

# %%
df_nyc_subset.to_csv('./Data/NYC_Health_Features.csv', index=False)
